# %% [markdown]
# # Stat 220, Unit 12 Homework: Capstone: Putting It Together
#
# This is the capstone. It is a full analysis plus the reasoning that goes with it, and
# the reasoning is worth more than the code.
#
# The first problem is **the five-beat drill** on scenarios that could come from any unit. The next
# three are a **complete analysis, a decision, and a forecast**. The last is a critique, which is the
# skill you will use most often and practice least.
#
# You will be graded on whether you *interrogated* the data as much as on whether you modeled it.
#
# **Data** (all real):
#
# - `https://richardson.byu.edu/220/insurance_all.csv`: annual medical charges per person.
# - `https://richardson.byu.edu/220/credit_risk.csv`: approved loans with a default indicator.
# - `https://richardson.byu.edu/220/bikes.csv`: daily bike-rental counts with weather.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
from sklearn.model_selection import train_test_split, cross_val_score, KFold

rng = np.random.default_rng(220)
ins = pd.read_csv("https://richardson.byu.edu/220/insurance_all.csv")
credit = pd.read_csv("https://richardson.byu.edu/220/credit_risk.csv")
bikes = pd.read_csv("https://richardson.byu.edu/220/bikes.csv")
print(ins.shape, credit.shape, bikes.shape)

# %% [markdown]
# **Problem 1.** *The five-beat drill.* For each scenario, write a complete answer using the five
# beats: clarify the question, state your assumptions, name your approach, name the traps, and say
# what would change your mind. Three to six sentences each. No code.

# %% [markdown]
# Part a. *"Signups are up 22% this week since we launched the new homepage. Roll it out
# everywhere."*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part b. *"Our churn model is 96% accurate with an AUC of 0.99. Can we act on it
# Monday?"*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part c. *"The campaign didn't work overall, but it was hugely effective for women aged
# 35 to 44 in the Midwest. Let's target them."*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part d. *"Customers who use our mobile app spend three times more. We should push everyone
# to install it."*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part e. *"Our hiring model is 88% accurate at predicting top performers. Let's screen
# applications with it."*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part f. *"Customer lifetime value is \$1,840. I've put it in the pricing model."*

# %% [markdown]
# _Your answer:_

# %% [markdown]
# **Problem 2.** *A full analysis.* A regional insurer wants to know **how much more it costs to
# cover a smoker**, in order to price a surcharge. Use `ins` and work the whole workflow, not just
# the model.

# %% [markdown]
# Part a. **Provenance first.** Describe what population this dataset plausibly represents,
# name two groups likely missing, and state what one observation is. Then examine `charges`: mean,
# median, skew, and a plot. Say which summary the insurer's question calls for and why.

# %% [markdown]
# Part b. Compute the raw difference in mean charges between smokers and non-smokers with a
# bootstrap 95% interval. State the number the way you would in a memo.

# %% [markdown]
# Part c. Fit a regression of `charges` on `smoker`, `age`, `bmi`, `children`, and `region`.
# Report the smoker coefficient with its interval and explain what changed relative to Part b.

# %% [markdown]
# Part d. Check the model: plot residuals against fitted values, identify the problem, refit
# with $\log(\text{charges})$, and explain how the smoker coefficient's interpretation changes on
# the log scale.

# %% [markdown]
# Part e. The insurer wants to say smoking *causes* these costs. State what would have to be
# true, name two confounders absent from the data, and say whether you would defend causal language
# in a regulatory filing.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part f. Write the final recommendation in 4 to 6 sentences: the surcharge number, its
# uncertainty, the assumption it rests on, and the one thing that would change your advice.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# **Problem 3.** *A decision under uncertainty.* Use `credit`. A lender will use a model to decide
# whom to approve. A default costs \$4,000 on average. Rejecting an applicant who would have repaid costs
# \$900 in forgone profit.

# %% [markdown]
# Part a. Split the data, fit a logistic regression of `loan_status` on `person_income`,
# `loan_amnt`, `loan_int_rate`, and `person_age`, and report held-out AUC and the trivial
# baseline's accuracy.

# %% [markdown]
# Part b. Sweep the approval threshold, compute total cost at each, and report the
# cost-minimizing threshold alongside the cost at 0.5. Report the savings per 1,000 applicants.

# %% [markdown]
# Part c. State the operating point in business language: what fraction are approved, what
# fraction of those default, and what fraction of good applicants are turned away.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part d. Check calibration by binning predicted probabilities against observed default
# rates. Explain why calibration specifically matters for the expected-cost calculation you just
# did.

# %% [markdown]
# Part e. This dataset contains only approved loans and has a default rate far above any real
# portfolio. Explain both problems and state, with direction, how each one distorts the threshold you
# chose.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# **Problem 4.** *A forecast with honest uncertainty.* Use `bikes`. An operations team must decide
# how many bikes to deploy each morning. Each bike costs \$3 for the day and each rental earns \$9.

# %% [markdown]
# Part a. Report the lag-1 autocorrelation of `Count` and explain what it implies about
# splitting the data. Then split the year into a training period and a later held-out period rather
# than at random, and justify that choice.

# %% [markdown]
# Part b. Fit a model predicting `Count` from the weather variables. Report training RMSE,
# held-out RMSE, and the RMSE of the trivial "predict the average" baseline.

# %% [markdown]
# Part c. Build a 90% prediction interval from held-out residuals for a day with temperature
# 20, humidity 50, wind 2, visibility 1500, rainfall 0. Then check the interval's actual coverage on
# data used for neither fitting nor calibration.

# %% [markdown]
# Part d. Using the predictive distribution rather than the point forecast, choose the fleet
# size that maximizes expected profit. Report it, and explain why it is not equal to the point
# forecast.

# %% [markdown]
# Part e. Predict for a day at 40 degrees, hotter than anything observed. Report the number,
# then explain what is dangerous about it and what you would tell the team instead.

# %% [markdown]
# Part f. Write the 4 to 6 sentence recommendation for the operations team, including the
# fleet size, the expected profit, the interval, and the two conditions under which you would revisit
# it.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# **Problem 5.** *The critique.* Below is a summary a colleague wrote. Take it apart, then rebuild
# it.

# %% [markdown]
# > *"We analyzed 1,500 loans and found that borrowers who rent default at 57%, versus 29%
# > for homeowners, a 97% higher default rate (chi-square p < 0.001). We also tested 14 other
# > variables and found that loan purpose matters (p = 0.03). Our random forest achieved 89%
# > accuracy, and feature importance shows income is the most important driver of default.
# > Recommendation: stop lending to renters and to applicants with low income."*

# %% [markdown]
# Part a. Identify at least **six** distinct statistical problems with that paragraph. For
# each, name the error and say why it matters here specifically.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part b. Verify two of its numerical claims against the data: the default rates by home
# ownership, and the accuracy of a random forest compared to predicting the majority class. Report
# what you find.

# %% [markdown]
# Part c. Rewrite the paragraph as you would present it, keeping every claim the data
# supports and qualifying or removing the rest. Aim for 5 to 8 sentences.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part d. Beyond the statistics, state one fairness or legal concern with the proposed policy,
# and explain how a model trained on historical approvals could encode it even with no protected
# attribute in the data.

# %% [markdown]
# _Your answer:_

# %% [markdown]
# Part e. Write the single most important question you would have asked before any of this
# analysis began, and explain in two sentences why it outranks everything else on your list.

# %% [markdown]
# _Your answer:_
